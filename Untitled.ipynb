# %%
import numpy as np
from matplotlib import pyplot as plt 
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %%
all_attributes = []
with open("all_attributes.txt", "r") as file:
    lines = file.readlines()
    for line in lines:
        all_attributes.append(line.rstrip())

# %%
word_embeddings = {}
count = 0
with open("./word_embeddings/glove.6B.300d.txt", "r") as file:
    while True:
        line = file.readline()
        key = line.split(" ")[0]
        val = np.array([float(x) for x in line.split(" ")[1:]])
        word_embeddings[key] = val
        
        count += 1
        if not line:
            print("Total words: {}".format(count))
            break
# Out:
# Total words: 400002

# %%
attribute_embeddings = {}
for attr in all_attributes:
    attr_list = attr.split(" ")
    attribute_embeddings[attr] = 0
    for att in attr_list:
        attribute_embeddings[attr] += word_embeddings[att]

labels = list(attribute_embeddings.keys())        
data = np.stack(list(attribute_embeddings.values()))
print(data.shape)
# Out:
# (617, 300)

# %%
pca = PCA(n_components=2)
X_cap = pca.fit_transform(data)

# %%
# %matplotlib notebook
f = plt.figure()
s = plt.scatter(x = X_cap[:, 0], y = X_cap[:, 1], c = data_cluster, cmap="jet")
for i, label in enumerate(labels):
    plt.text(X_cap[i, 0], X_cap[i, 1], label, fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tsne = TSNE(n_components=2)
X_cap = tsne.fit_transform(data)

# %%
# %matplotlib notebook
f = plt.figure()
s = plt.scatter(x = X_cap[:, 0], y = X_cap[:, 1], c=data_cluster, cmap="jet")
for i, label in enumerate(labels):
    plt.text(X_cap[i, 0], X_cap[i, 1], label, fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="981">

# %%
attrCategories = []
with open("query_args.txt", "r") as file:
    lines = file.readlines()
    
    for line in lines:
        attrCategories.append(line.rstrip())

cat_embeddings = {}
for cat in attrCategories:
    cat_list = cat.split(" ")
    if cat == "hposition":
        cat_list = ["horizontal", "position"]
    elif cat == "sportActivity":
        cat_list = ["sports", "activity"]
    cat_embeddings[cat] = 0
    for catg in cat_list:
        cat_embeddings[cat] += word_embeddings[catg]
    
cat_labels = list(cat_embeddings.keys())
cat_data = list(cat_embeddings.values())

# %%
kmeans = KMeans(n_clusters=len(cat_data)-1)
data_cluster = np.argmin(kmeans.fit_transform(data), axis=1)
cluster_means = kmeans.cluster_centers_

# %%
print(labels[0])
print(data_cluster[0])
# Out:
# abandoned
# 19

# %%
cluster_means
# Out:
# array([[-0.00876336, -0.03532551,  0.04243407, ..., -0.16967746,
#          0.1882872 , -0.14144322],
#        [ 0.0118804 ,  0.0481226 ,  0.1189316 , ..., -0.328234  ,
#         -0.0221728 ,  0.1943306 ],
#        [ 0.09138201,  0.18758328,  0.35507283, ..., -0.21838945,
#         -0.11375959, -0.03044972],
#        ...,
#        [-0.489835  , -0.113794  , -0.395213  , ..., -0.582945  ,
#         -0.813548  ,  1.266305  ],
#        [-0.50599328, -0.2881375 ,  0.41328725, ...,  0.463607  ,
#          0.31049   ,  0.02415   ],
#        [ 0.00323557, -0.18018757,  0.16317457, ..., -0.15472729,
#          0.54121286,  0.113512  ]])

# %%
cat_clusters = np.argmin(kmeans.transform(cat_data), axis=1)

# %%
for i, label in enumerate(cat_labels):
    print("{} : {}".format(label, cat_clusters[i]))
# Out:
# activity : 12
# age : 12
# cleanliness : 4
# color : 3
# company : 12
# depth : 12
# face expression : 12
# fatness : 10
# flavor : 8
# gender : 12
# hardness : 4
# height : 0
# hposition : 20
# length : 9
# material : 19
# name : 12
# pattern : 28
# place : 12
# pose : 14
# race : 12
# realism : 28
# room : 19
# shape : 22
# size : 19
# sport : 6
# sportActivity : 6
# state : 12
# texture : 25
# thickness : 22
# tone : 28
# weather : 15
# weight : 12
# width : 22

# %%
attribute_categories = {}
for i, label in enumerate(labels):
    try:
        attribute_categories[data_cluster[i]].append(label)
    except:
        attribute_categories[data_cluster[i]] = [label]

# %%
attribute_categories
# Out:
# {19: ['abandoned',
#   'bare',
#   'blank',
#   'burning',
#   'burnt',
#   'christmas',
#   'clay',
#   'covered',
#   'crowded',
#   'crystal',
#   'damaged',
#   'disposable',
#   'empty',
#   'fake',
#   'filled',
#   'floating',
#   'garbage',
#   'gas',
#   'hollow',
#   'homemade',
#   'kitchen',
#   'lined',
#   'lit',
#   'ocean',
#   'oriental',
#   'outdoor',
#   'packed',
#   'palm',
#   'paper',
#   'plastic',
#   'portable',
#   'rock',
#   'scarce',
#   'scattered',
#   'sealed',
#   'shallow',
#   'small',
#   'soap',
#   'spraying',
#   'spread',
#   'square',
#   'straw',
#   'tiny',
#   'toilet',
#   'torn',
#   'trash',
#   'urban',
#   'vacant',
#   'vast',
#   'water',
#   'wedding',
#   'wood'],
#  27: ['abstract',
#   'antique',
#   'brass',
#   'bronze',
#   'carved',
#   'ceramic',
#   'decorated',
#   'decorative',
#   'displayed',
#   'framed',
#   'glass',
#   'glazed',
#   'illuminated',
#   'inflatable',
#   'lighted',
#   'miniature',
# ...

# %%
kmeans.n_iter_
# Out:
# 10
